# %%
import numpy as np
from scipy.fftpack import dct, idct
from scipy.signal import convolve2d
from matplotlib import pyplot as plt
import time

# %%
rootfolder = '..'

# %% [markdown]
# Definition of dct2 and idct2 (they are not builtin functions)

# %%
def dct2(s):
    return dct(dct(s.T, norm='ortho').T, norm='ortho')

def idct2(x):
    return idct(idct(x.T, norm='ortho').T, norm='ortho')

# %% [markdown]
# Useful function for plot the 2D DCT dictionary

# %%
def get_dictionary_img(D):
    M = D.shape[0]
    p = int(round(np.sqrt(M)))
    bound = 2
    img = np.ones((p*p+bound*(p-1), p*p+bound*(p-1)))
    for i in range(M):
        m = np.mod(i, p)
        n = int((i-m)/p)
        m = m * p + bound * m
        n = n * p + bound * n
        atom = D[:, i].reshape((p, p))
        if atom.min() < atom.max():
            atom = (atom - atom.min()) / (atom.max() - atom.min())
        img[m: m + p, n: n + p] = atom

    return img

# %% [markdown]
# Load the image and rescale it in $[0,1]$

# %%
img = plt.imread(f'{rootfolder}/data/cameraman.png')
imsz = img.shape

# patch size
p = 8

# number of elements in the patch
M = p ** 2

# %% [markdown]
# Corrupt the image with white gaussian noise

# %%
sigma_noise = 20/255
noisy_img = img + np.random.normal(size=imsz) * sigma_noise

# %% [markdown]
# Compute the psnr of the noisy input

# %%
def calculate_psnr (I, I_prime):
    return 10 * np.log10(1 / np.mean((I - I_prime) ** 2))

psnr_noisy = calculate_psnr(noisy_img, img)
psnr_noisy
# Out:
# 22.07320683804571

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 10))
ax[0].imshow(img, cmap='gray')
ax[0].set_title('Original image')

ax[1].imshow(noisy_img, cmap='gray')
ax[1].set_title(f'Noisy image, PSNR = {psnr_noisy:.2f}')
# Out:
# Text(0.5, 1.0, 'Noisy image, PSNR = 22.07')

# %% [markdown]
# DCT denoising
# -------------
# Generate the DCT basis

# %%
def canonical(shape, i, j):
    e = np.zeros(shape)
    e[i, j] = 1
    return e

# %%
D = np.zeros((M, M))
cnt = 0
for i in range(p):
    for j in range(p):
        D[:, cnt] = idct2(canonical((p, p), i, j)).flatten()
        cnt += 1

# %%
D_img = get_dictionary_img(D)
plt.figure(figsize=(8, 8))
plt.imshow(D_img, cmap='gray')

# %% [markdown]
# Denoising: set parameters and initialize the variables

# %%
# initialize the estimated image
img_hat = np.zeros_like(img)

# initialize the weight matrix
weights = np.zeros_like(img)

# set the threshold for the Hard Thresholding
tau = 3 * sigma_noise # Donoho says: sigma * sqrt(2*log(p^2))

# define the step
STEP = 1

# %% [markdown]
# Perform the denoising pathwise

# %%
for i in range(0, imsz[0] - p + 1, STEP):
    for j in range(0, imsz[1] - p + 1, STEP):
        # extrach the patch with the top left corner at pixel (ii, jj)
        s = noisy_img[i:i+p, j:j+p]

        # compute the representation w.r.t. the 2D DCT dictionary
        x = D.T @ s.flatten()

        # perform the hard thresholding (do not perform HT on the DC!)
        x_HT = x.copy()
        x_HT[np.abs(x_HT) <= tau] = 0
        x_HT[0] = x[0]

        # perform the reconstruction
        s_hat = D @ x_HT

        # compute the weight for the reconstructed patch
        w = 1 / np.max([1, np.sum(x_HT == 0)])

        # put the compressed patch into the compressed image using the computed weight
        # update img_hat
        img_hat[i:i+p, j:j+p] += (s_hat * w).reshape(p, p)

        # store the weight of the current patch in the weight matrix
        # update weights
        weights[i:i+p, j:j+p] += w

# %% [markdown]
# Normalize the estimated image with the computed weights

# %%
img_hat /= weights
# img_hat /= img_hat.max()

# %% [markdown]
# Compute the psnr of the estimated image

# %%
psnr = calculate_psnr(img_hat, img)
plt.figure(figsize=(10,10))
plt.imshow(img_hat, cmap='gray')
plt.title(f'Estimated Image,\nPSNR = {psnr:.2f}')
# Out:
# Text(0.5, 1.0, 'Estimated Image,\nPSNR = 29.16')

# %% [markdown]
# Wiener Filtering
# ----------------
# Initialize the estimated image via Wiener Filtering

# %%
img_hat_wiener = np.zeros_like(img)
weights = np.zeros_like(img)

# %% [markdown]
# Perform the denoising patchwise

# %%
for i in range(0, imsz[0] - p + 1, STEP):
    for j in range(0, imsz[1] - p + 1, STEP):
        # extrach the patch from the noisy image with the top left corner at pixel (ii, jj)
        s = noisy_img[i:i+p, j:j+p]

        # compute the representation w.r.t. the 2D DCT dictionary
        x = D.T @ s.flatten()

        # extrach the patch from the image estimated by HT with the top left corner at pixel (ii, jj)
        s_hat_HT = img_hat[i:i+p, j:j+p]

        # perform the wiener filtering (do not filter the DC!)
        u = D.T @ s_hat_HT.flatten()
        x_wie = u ** 2 / (sigma_noise ** 2 + u ** 2) * x 
        x_wie[0] = x[0]

        # perform the reconstruction
        s_hat_wie = D @ x_wie

        # use uniform weights to aggregate the multiple estimates
        w = 1

        # put the compressed patch into the compressed image using the computed weight
        # update img_hat_wiener
        img_hat_wiener[i:i+p, j:j+p] += w * s_hat_wie.reshape(p, p)

        # store the weight of the current patch in the weight matrix
        # update weights
        weights[i:i+p, j:j+p] += w

# Normalize the estimated image with the computed weights
img_hat_wiener /= weights

# %% [markdown]
# Compute the psnr of the two estimates

# %%
psnr_wiener = calculate_psnr(img_hat_wiener, img)

fig, ax = plt.subplots(1, 2, figsize=(20, 10))
ax[0].imshow(img_hat, cmap='gray')
ax[0].set_title(f'HT Estimate, PSNR = {psnr:.2f}')

ax[1].imshow(img_hat_wiener, cmap='gray')
ax[1].set_title(f'Wiener Estimate, PSNR = {psnr_wiener:.2f}')
# Out:
# Text(0.5, 1.0, 'Wiener Estimate, PSNR = 29.40')

# %% [markdown]
# Noise estimation
# ----------------
# Compute the horizontal derivative of the image

# %%
differences = np.diff(noisy_img, axis=1)

# %% [markdown]
# Compute sigma as the empirical std

# %%
sigma_hat_emp = differences.std() / np.sqrt(2)
sigma_hat_emp
# Out:
# 0.10081512377898946

# %% [markdown]
# Use MAD to estimate the noise level sigma

# %%
sigma_hat = np.median(np.abs(differences - np.median(differences)))
sigma_hat /= np.sqrt(2) * 0.67449
sigma_hat
# Out:
# 0.08679218256327016

# %%
print(f'sigma: {sigma_noise:.3f}, sigma_hat (empirical std): {sigma_hat_emp:.3f}, sigma_hat (MAD): {sigma_hat:.3f}')
# Out:
# sigma: 0.078, sigma_hat (empirical std): 0.101, sigma_hat (MAD): 0.087
